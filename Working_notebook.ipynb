# %%
# Import Dependencies
import pandas as pd
from pathlib import Path

# %%
# Make a reference to the comic_books_expanded.csv file path
csv_path = Path("Netflix_data.csv")

# Import the comic_books_expanded.csv file as a DataFrame
Netflix_df = pd.read_csv(csv_path, encoding="utf-8")

# %%
Netflix_df.head()
# Out:
#                                  Title Available Globally? Release Date  \
# 0            The Night Agent: Season 1                 Yes   2023-03-23
# 1            Ginny & Georgia: Season 2                 Yes   2023-01-05
# 2   The Glory: Season 1 // 더 글로리: 시즌 1                 Yes   2022-12-30
# 3                  Wednesday: Season 1                 Yes   2022-11-23
# 4  Queen Charlotte: A Bridgerton Story                 Yes   2023-05-04
#
#    Hours Viewed  Number of Ratings  Rating                              Genre  \
# 0     812100000             7696.0     6.0  ['Biography', 'Drama', 'History']
# 1     665100000             5216.0     5.7     ['Comedy', 'Drama', 'Romance']
# 2     622800000            11869.0     8.4                          ['Short']
# 3     507700000                NaN     NaN                      ['Talk-Show']
# 4     503000000            50077.0     7.4    ['Drama', 'History', 'Romance']
#
#                                            Key Words  \
# ...

# %%
test_df = Netflix_df[Netflix_df["Rating"].isnull()]
test_df.head(100)
# Out:
#                                                 Title Available Globally?  \
# 3                                 Wednesday: Season 1                 Yes
# 7                               Outer Banks: Season 3                 Yes
# 10                                 Manifest: Season 4                 Yes
# 11                       Kaleidoscope: Limited Series                 Yes
# 12                             Firefly Lane: Season 2                 Yes
# ..                                                ...                 ...
# 284                                      Blood & Gold                 Yes
# 286                           The Blacklist: Season 5                  No
# 287  Little Women: Limited Series // 작은 아씨들: 리미티드 시리즈                  No
# 297                                          2 Hearts                  No
# 298                            Suits (2011): Season 6                 Yes
#
#     Release Date  Hours Viewed  Number of Ratings  Rating  \
# ...
