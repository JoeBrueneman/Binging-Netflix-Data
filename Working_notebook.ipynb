# %%
# Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import json

# %%
# Read the 'Netflix_Engagement_Plus.csv'data file as Netflix_df
Netflix_df = pd.read_excel("Resources/Netflix_Engagement_Report.xlsx", header=5)
Netflix_df = Netflix_df.drop(['Unnamed: 0'], axis=1)

# %%
Netflix_df
# Out:
#                                      Title Available Globally? Release Date  \
# 0                The Night Agent: Season 1                 Yes   2023-03-23
# 1                Ginny & Georgia: Season 2                 Yes   2023-01-05
# 2       The Glory: Season 1 // 더 글로리: 시즌 1                 Yes   2022-12-30
# 3                      Wednesday: Season 1                 Yes   2022-11-23
# 4      Queen Charlotte: A Bridgerton Story                 Yes   2023-05-04
# ...                                    ...                 ...          ...
# 18209                            راس السنة                  No          NaT
# 18210                         心が叫びたがってるんだ。                  No          NaT
# 18211                            두근두근 내 인생                  No          NaT
# 18212                               라디오 스타                  No          NaT
# 18213                               선생 김봉두                  No          NaT
#
#        Hours Viewed
# 0         812100000
# 1         665100000
# 2         622800000
# 3         507700000
# 4         503000000
# ...             ...
# 18209        100000
# 18210        100000
# 18211        100000
# 18212        100000
# 18213        100000
#
# [18214 rows x 4 columns]

# %%
# Clean up Title name and split off OriginalTitle and Year_Country
Netflix2_df = Netflix_df
Netflix2_df['originalTitle'] = Netflix2_df['Title'].str.extract('(?:\/\/)(.{1,})')
Netflix2_df['Title'] = Netflix2_df['Title'].str.replace('\/\/.{1,}', '', regex=True)
Netflix2_df['Title'] = Netflix2_df['Title'].str.replace('\:\sSeason\s\d+', '', regex=True)
Netflix2_df['Year_Country'] = Netflix2_df['Title'].str.extract('(?:\()(.+(?=\)))')
Netflix2_df['Title'] = Netflix2_df['Title'].str.replace('\(.+', '', regex=True)
Netflix2_df['Title'] = Netflix2_df['Title'].str.strip()
Netflix2_df.head()
# Out:
#                                  Title Available Globally? Release Date  \
# 0                      The Night Agent                 Yes   2023-03-23
# 1                      Ginny & Georgia                 Yes   2023-01-05
# 2                            The Glory                 Yes   2022-12-30
# 3                            Wednesday                 Yes   2022-11-23
# 4  Queen Charlotte: A Bridgerton Story                 Yes   2023-05-04
#
#    Hours Viewed originalTitle Year_Country
# 0     812100000           NaN          NaN
# 1     665100000           NaN          NaN
# 2     622800000   더 글로리: 시즌 1          NaN
# 3     507700000           NaN          NaN
# 4     503000000           NaN          NaN

# %%
# Merge, and clean up the Netflix data so that all seasons have their hours viewed combined
df = Netflix2_df[['Title','Hours Viewed']]
df = pd.DataFrame(df.groupby(by='Title').sum())
df = pd.merge(df,Netflix2_df, on='Title', how='left')
df = df.sort_values(by=['Release Date'])
df = df.drop_duplicates(subset=['Title'])
df = df.drop(columns=['Hours Viewed_y'])
df = df.rename(columns={'Hours Viewed_x':'Hours Viewed'})
df['Title'] = df['Title'].str.lower()
df
# Out:
#                       Title  Hours Viewed Available Globally? Release Date  \
# 1164   arrested development      41300000                  No   2010-04-01
# 16676     trailer park boys      78100000                 Yes   2010-09-22
# 7904       la reina del sur     616800000                  No   2011-09-05
# 8253             lilyhammer       7800000                  No   2012-02-06
# 6400         house of cards      68900000                  No   2013-02-01
# ...                     ...           ...                 ...          ...
# 18209                  레드슈즈        200000                  No          NaT
# 18210                  비상선언      18600000                  No          NaT
# 18211                선생 김봉두        100000                  No          NaT
# 18212                    침묵        400000                  No          NaT
# 18213                    표적        200000                  No          NaT
#
#       originalTitle Year_Country
# 1164            NaN          NaN
# 16676           NaN          NaN
# 7904            NaN          NaN
# 8253            NaN          NaN
# 6400            NaN          NaN
# ...             ...          ...
# 18209           NaN          NaN
# 18210           NaN          NaN
# 18211           NaN          NaN
# 18212           NaN          NaN
# 18213           NaN          NaN
#
# [15278 rows x 6 columns]

# %%
# Read the 'Data_Title'data file as title_df
title_df = pd.read_csv("Resources/data_title.tsv",sep = '\t') 
title_df.head()
# Out:
# C:\Users\Joey\AppData\Local\Temp\ipykernel_10724\146890606.py:2: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   title_df = pd.read_csv("Resources/data_title.tsv",sep = '\t')
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
# Clean up ImDB Title information to remove enneccesary information
Filtered_title_df = title_df[~title_df['titleType'].isin(['videoGame', 'tvPilot', 'tvEpisode'])]
Filtered_title_df = Filtered_title_df.rename(columns={'primaryTitle':'Title'})
Filtered_title_df['Title'] = Filtered_title_df['Title'].str.lower()
Filtered_title_df
# Out:
#              tconst titleType                           Title  \
# 0         tt0000001     short                      carmencita
# 1         tt0000002     short          le clown et ses chiens
# 2         tt0000003     short                  pauvre pierrot
# 3         tt0000004     short                     un bon bock
# 4         tt0000005     short                blacksmith scene
# ...             ...       ...                             ...
# 10415838  tt9916730     movie                          6 gunn
# 10415848  tt9916754     movie  chico albuquerque - revelações
# 10415849  tt9916756     short        pretty pretty black girl
# 10415853  tt9916764     short                              38
# 10415896  tt9916856     short                        the wind
#
#                            originalTitle isAdult startYear endYear  \
# 0                             Carmencita       0      1894      \N
# 1                 Le clown et ses chiens       0      1892      \N
# 2                         Pauvre Pierrot       0      1892      \N
# 3                            Un bon bock       0      1892      \N
# 4                       Blacksmith Scene       0      1893      \N
# ...                                  ...     ...       ...     ...
# 10415838                          6 Gunn       0      2017      \N
# 10415848  Chico Albuquerque - Revelações       0      2013      \N
# 10415849        Pretty Pretty Black Girl       0      2019      \N
# 10415853                              38       0      2018      \N
# 10415896                        The Wind       0      2015      \N
#
#          runtimeMinutes                    genres
# 0                     1         Documentary,Short
# 1                     5           Animation,Short
# 2                     4  Animation,Comedy,Romance
# 3                    12           Animation,Short
# 4                     1              Comedy,Short
# ...                 ...                       ...
# 10415838            116                     Drama
# 10415848             49               Documentary
# 10415849             \N                     Short
# 10415853             \N                     Short
# 10415896             27                     Short
#
# [2423657 rows x 9 columns]

# %%
# Merge Netflix and IMDB information
Merged_df = pd.merge(df,Filtered_title_df, on='Title', how='left')
Merged_df
# Out:
#                       Title  Hours Viewed Available Globally? Release Date  \
# 0      arrested development      41300000                  No   2010-04-01
# 1      arrested development      41300000                  No   2010-04-01
# 2      arrested development      41300000                  No   2010-04-01
# 3         trailer park boys      78100000                 Yes   2010-09-22
# 4         trailer park boys      78100000                 Yes   2010-09-22
# ...                     ...           ...                 ...          ...
# 81286                  레드슈즈        200000                  No          NaT
# 81287                  비상선언      18600000                  No          NaT
# 81288                선생 김봉두        100000                  No          NaT
# 81289                    침묵        400000                  No          NaT
# 81290                    표적        200000                  No          NaT
#
#       originalTitle_x Year_Country     tconst titleType       originalTitle_y  \
# 0                 NaN          NaN  tt0367279  tvSeries  Arrested Development
# 1                 NaN          NaN  tt0376489     short  Arrested Development
# 2                 NaN          NaN  tt0901469     movie  Arrested Development
# 3                 NaN          NaN  tt0290988  tvSeries     Trailer Park Boys
# 4                 NaN          NaN  tt0383678     movie     Trailer Park Boys
# ...               ...          ...        ...       ...                   ...
# 81286             NaN          NaN        NaN       NaN                   NaN
# 81287             NaN          NaN        NaN       NaN                   NaN
# 81288             NaN          NaN        NaN       NaN                   NaN
# 81289             NaN          NaN        NaN       NaN                   NaN
# 81290             NaN          NaN        NaN       NaN                   NaN
#
#       isAdult startYear endYear runtimeMinutes        genres
# 0           0      2003    2019             22        Comedy
# 1           0      2003      \N              6         Short
# 2           0        \N      \N             \N        Comedy
# 3           0      2001    2018             30  Comedy,Crime
# 4           0      1999      \N             67        Comedy
# ...       ...       ...     ...            ...           ...
# 81286     NaN       NaN     NaN            NaN           NaN
# 81287     NaN       NaN     NaN            NaN           NaN
# 81288     NaN       NaN     NaN            NaN           NaN
# 81289     NaN       NaN     NaN            NaN           NaN
# 81290     NaN       NaN     NaN            NaN           NaN
#
# [81291 rows x 14 columns]

# %%
# Test dataframe to see how many records are still null and not matching to any record from the IMDB data
test_df = test_df[test_df['tconst'].isnull()]
test_df
# Out:
#                                              Title  Hours Viewed  \
# 123                mako mermaids: an h2o adventure      50600000
# 182    ever after high: welcome to ever after high       4600000
# 183       trailer park boys live in f**kin' dublin        100000
# 187                           jim jefferies : bare        500000
# 195     chelsea handler: uganda be kidding me live        200000
# ...                                            ...           ...
# 81286                                         레드슈즈        200000
# 81287                                         비상선언      18600000
# 81288                                       선생 김봉두        100000
# 81289                                           침묵        400000
# 81290                                           표적        200000
#
#       Available Globally? Release Date originalTitle_x Year_Country tconst  \
# 123                    No   2013-07-26             NaN          NaN    NaN
# 182                   Yes   2014-01-31             NaN          NaN    NaN
# 183                   Yes   2014-05-31             NaN          NaN    NaN
# 187                    No   2014-08-29             NaN          NaN    NaN
# 195                    No   2014-10-10             NaN          NaN    NaN
# ...                   ...          ...             ...          ...    ...
# 81286                  No          NaT             NaN          NaN    NaN
# 81287                  No          NaT             NaN          NaN    NaN
# 81288                  No          NaT             NaN          NaN    NaN
# 81289                  No          NaT             NaN          NaN    NaN
# 81290                  No          NaT             NaN          NaN    NaN
#
#       titleType originalTitle_y isAdult startYear endYear runtimeMinutes  \
# 123         NaN             NaN     NaN       NaN     NaN            NaN
# 182         NaN             NaN     NaN       NaN     NaN            NaN
# 183         NaN             NaN     NaN       NaN     NaN            NaN
# 187         NaN             NaN     NaN       NaN     NaN            NaN
# 195         NaN             NaN     NaN       NaN     NaN            NaN
# ...         ...             ...     ...       ...     ...            ...
# 81286       NaN             NaN     NaN       NaN     NaN            NaN
# 81287       NaN             NaN     NaN       NaN     NaN            NaN
# 81288       NaN             NaN     NaN       NaN     NaN            NaN
# 81289       NaN             NaN     NaN       NaN     NaN            NaN
# 81290       NaN             NaN     NaN       NaN     NaN            NaN
#
#       genres
# 123      NaN
# 182      NaN
# 183      NaN
# 187      NaN
# 195      NaN
# ...      ...
# 81286    NaN
# 81287    NaN
# 81288    NaN
# 81289    NaN
# 81290    NaN
#
# [3725 rows x 14 columns]
