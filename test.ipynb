# %%
import pandas as pd
from pathlib import Path

# %%
data = pd.read_csv('title.basics.tsv', sep='\t')
# Out:
# /Users/juliamin/anaconda3/envs/PythonData/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
data.head(50)
# Out:
#        tconst titleType                                   primaryTitle  \
# 0   tt0000001     short                                     Carmencita
# 1   tt0000002     short                         Le clown et ses chiens
# 2   tt0000003     short                                 Pauvre Pierrot
# 3   tt0000004     short                                    Un bon bock
# 4   tt0000005     short                               Blacksmith Scene
# 5   tt0000006     short                              Chinese Opium Den
# 6   tt0000007     short    Corbett and Courtney Before the Kinetograph
# 7   tt0000008     short         Edison Kinetoscopic Record of a Sneeze
# 8   tt0000009     movie                                     Miss Jerry
# 9   tt0000010     short                            Leaving the Factory
# 10  tt0000011     short                        Akrobatisches Potpourri
# 11  tt0000012     short                         The Arrival of a Train
# ...

# %%
data_2 = pd.read_csv('title.ratings.tsv', sep='\t')

# %%
data_2.tail()
# Out:
#             tconst  averageRating  numVotes
# 1381656  tt9916730            7.6        11
# 1381657  tt9916766            7.0        22
# 1381658  tt9916778            7.2        36
# 1381659  tt9916840            8.8         6
# 1381660  tt9916880            8.2         6

# %%
data_df = pd.merge(data, data_2, on ="tconst")

# %%
data_df.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres  \
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short
#
#    averageRating  numVotes
# 0            5.7      2008
# 1            5.7       270
# 2            6.5      1926
# ...

# %%
netflix_data = pd.read_csv('Netflix Engagement (plus).csv')
netflix_data
# Out:
#                                      Title Available Globally? Release Date  \
# 0                The Night Agent: Season 1                 Yes   2023-03-23
# 1                Ginny & Georgia: Season 2                 Yes   2023-01-05
# 2       The Glory: Season 1 // 더 글로리: 시즌 1                 Yes   2022-12-30
# 3                      Wednesday: Season 1                 Yes   2022-11-23
# 4      Queen Charlotte: A Bridgerton Story                 Yes   2023-05-04
# ...                                    ...                 ...          ...
# 18327                            راس السنة                  No          NaN
# 18328                         心が叫びたがってるんだ。                  No          NaN
# 18329                            두근두근 내 인생                  No          NaN
# 18330                               라디오 스타                  No          NaN
# 18331                               선생 김봉두                  No          NaN
#
#        Hours Viewed  Number of Ratings  Rating  \
# ...

# %%
test_df = netflix_data[netflix_data["Rating"].isnull()]
test_df
# Out:
#                                Title Available Globally? Release Date  \
# 3                Wednesday: Season 1                 Yes   2022-11-23
# 7              Outer Banks: Season 3                 Yes   2023-02-23
# 10                Manifest: Season 4                 Yes   2022-11-04
# 11      Kaleidoscope: Limited Series                 Yes   2023-01-01
# 12            Firefly Lane: Season 2                 Yes   2022-12-02
# ...                              ...                 ...          ...
# 18325  حكايات بنات الجزء ١: Season 2                  No          NaN
# 18326  حكايات بنات الجزء ١: Season 3                  No          NaN
# 18329                      두근두근 내 인생                  No          NaN
# 18330                         라디오 스타                  No          NaN
# 18331                         선생 김봉두                  No          NaN
#
#        Hours Viewed  Number of Ratings  Rating                     Genre  \
# ...

# %%
data_df = data_df.rename(columns={"primaryTitle":"Title"})
data_df.head()
# Out:
#       tconst titleType                   Title           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres  \
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short
#
#    averageRating  numVotes
# 0            5.7      2008
# 1            5.7       270
# 2            6.5      1926
# ...

# %%
merge_df = pd.merge(test_df, data_df, on ="Title")
merge_df
# Out:
#                   Title Available Globally? Release Date  Hours Viewed  \
# 0                   AKA                 Yes   2023-04-28     120000000
# 1                   AKA                 Yes   2023-04-28     120000000
# 2                   AKA                 Yes   2023-04-28     120000000
# 3     Stranger Things 3                 Yes   2019-07-04      67000000
# 4          The Gray Man                 Yes   2022-07-22      58300000
# ...                 ...                 ...          ...           ...
# 1007        Wild Venice                  No          NaN        100000
# 1008                Zog                  No          NaN        100000
# 1009               Zulu                  No          NaN        100000
# 1010               Zulu                  No          NaN        100000
# 1011               Zulu                  No          NaN        100000
#
#       Number of Ratings  Rating                             Genre Key Words  \
# ...
