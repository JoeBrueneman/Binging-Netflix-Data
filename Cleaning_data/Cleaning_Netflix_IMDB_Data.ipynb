# %%
# Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import json

# %%
# Read the 'Netflix_Engagement_Plus.csv'data file as Netflix_df
Netflix_df = pd.read_excel("Resources/Netflix_Engagement_Report.xlsx", header=5)
Netflix_df = Netflix_df.drop(['Unnamed: 0'], axis=1)
Netflix_df
# Out:
#                                      Title Available Globally? Release Date  \
# 0                The Night Agent: Season 1                 Yes   2023-03-23
# 1                Ginny & Georgia: Season 2                 Yes   2023-01-05
# 2       The Glory: Season 1 // 더 글로리: 시즌 1                 Yes   2022-12-30
# 3                      Wednesday: Season 1                 Yes   2022-11-23
# 4      Queen Charlotte: A Bridgerton Story                 Yes   2023-05-04
# ...                                    ...                 ...          ...
# 18209                            راس السنة                  No          NaT
# 18210                         心が叫びたがってるんだ。                  No          NaT
# 18211                            두근두근 내 인생                  No          NaT
# 18212                               라디오 스타                  No          NaT
# 18213                               선생 김봉두                  No          NaT
#
#        Hours Viewed
# 0         812100000
# 1         665100000
# 2         622800000
# 3         507700000
# 4         503000000
# ...             ...
# 18209        100000
# 18210        100000
# 18211        100000
# 18212        100000
# 18213        100000
#
# [18214 rows x 4 columns]

# %%
# Clean up Title name and split off OriginalTitle and Year_Country
Netflix2_df = Netflix_df
Netflix2_df['originalTitle'] = Netflix2_df['Title'].str.extract('(?:\/\/)(.+(?=:))')
Netflix2_df['Title'] = Netflix2_df['Title'].str.replace('\/\/.{1,}', '', regex=True)
Netflix2_df['Title'] = Netflix2_df['Title'].str.replace('\:\sSeason\s\d+', '', regex=True)
Netflix2_df['Title'] = Netflix2_df['Title'].str.replace('\:\sPart\s\d+', '', regex=True)
Netflix2_df['Title'] = Netflix2_df['Title'].str.replace('\:\sBook\s\d+', '', regex=True)
Netflix2_df['Title'] = Netflix2_df['Title'].str.replace('\:\sVolume\s\d+', '', regex=True)
Netflix2_df['Title'] = Netflix2_df['Title'].str.replace('\:\sLimited\sSeries', '', regex=True)
Netflix2_df['Year_Country'] = Netflix2_df['Title'].str.extract('(?:\()(.+(?=\)))')
Netflix2_df['Title'] = Netflix2_df['Title'].str.replace('\(.+', '', regex=True)
Netflix2_df['Title'] = Netflix2_df['Title'].str.strip()
Netflix2_df['originalTitle'] = Netflix2_df['originalTitle'].str.strip()
Netflix2_df.head()
# Out:
#                                  Title Available Globally? Release Date  \
# 0                      The Night Agent                 Yes   2023-03-23
# 1                      Ginny & Georgia                 Yes   2023-01-05
# 2                            The Glory                 Yes   2022-12-30
# 3                            Wednesday                 Yes   2022-11-23
# 4  Queen Charlotte: A Bridgerton Story                 Yes   2023-05-04
#
#    Hours Viewed originalTitle Year_Country
# 0     812100000           NaN          NaN
# 1     665100000           NaN          NaN
# 2     622800000         더 글로리          NaN
# 3     507700000           NaN          NaN
# 4     503000000           NaN          NaN

# %%
# Merge, and clean up the Netflix data so that all seasons have their hours viewed combined
df = Netflix2_df[['Title','Hours Viewed']]
df = pd.DataFrame(df.groupby(by='Title').sum())
df = pd.merge(df,Netflix2_df, on='Title', how='left')
df = df.sort_values(by=['Release Date'])
df = df.drop_duplicates(subset=['Title'])
df = df.drop(columns=['Hours Viewed_y'])
df = df.rename(columns={'Hours Viewed_x':'Hours Viewed'})
df['Title'] = df['Title'].str.lower()
df
# Out:
#                       Title  Hours Viewed Available Globally? Release Date  \
# 1164   arrested development      41300000                  No   2010-04-01
# 16685     trailer park boys      78100000                 Yes   2010-09-22
# 7904       la reina del sur     616800000                  No   2011-09-05
# 8253             lilyhammer       7800000                  No   2012-02-06
# 6400         house of cards      68900000                  No   2013-02-01
# ...                     ...           ...                 ...          ...
# 18209                  레드슈즈        200000                  No          NaT
# 18210                  비상선언      18600000                  No          NaT
# 18211                선생 김봉두        100000                  No          NaT
# 18212                    침묵        400000                  No          NaT
# 18213                    표적        200000                  No          NaT
#
#       originalTitle Year_Country
# 1164            NaN          NaN
# 16685           NaN          NaN
# 7904            NaN          NaN
# 8253            NaN          NaN
# 6400            NaN          NaN
# ...             ...          ...
# 18209           NaN          NaN
# 18210           NaN          NaN
# 18211           NaN          NaN
# 18212           NaN          NaN
# 18213           NaN          NaN
#
# [15125 rows x 6 columns]

# %%
# Sort dataframe by hours viewed to review most watched shows after season data has been combined
df = df.sort_values(by=['Hours Viewed'], ascending=False)
df.head(50)
# Out:
#                                      Title  Hours Viewed Available Globally?  \
# 5379                       ginny & georgia     967200000                 Yes
# 15439                      the night agent     812100000                 Yes
# 17960                                  you     766300000                 Yes
# 10764                          outer banks     740400000                 Yes
# 16178                     the walking dead     738600000                  No
# 14713                            the glory     622800000                 Yes
# 7904                      la reina del sur     616800000                  No
# 2999                             cocomelon     601200000                  No
# 13394                                suits     599300000                 Yes
# 14084                        the blacklist     596900000                  No
# 8882                              manifest     581900000                  No
# 5704                        grey's anatomy     560300000                  No
# 17542                            wednesday     507700000                 Yes
# 2304                          breaking bad     505000000                  No
# 11514  queen charlotte: a bridgerton story     503000000                 Yes
# 5361                         gilmore girls     488700000                 Yes
# 5078                               friends     448500000                  No
# 8643                               lucifer     434300000                  No
# 14044                  the big bang theory     420400000                  No
# 12576                            shameless     392900000                  No
# 10116                        new amsterdam     375500000                  No
# 2355                    brooklyn nine-nine     358900000                  No
# 8497                         love is blind     343900000                 Yes
# 4843                          firefly lane     342700000                 Yes
# 10104                    never have i ever     341300000                 Yes
# 15479                           the office     341100000                  No
# 17343                    vikings: valhalla     322000000                 Yes
# 10807                           paw patrol     312600000                  No
# 12436                             seinfeld     311200000                 Yes
# 14595                            the flash     311000000                  No
# 9937                                  ncis     310800000                  No
# 15275                     the marked heart     307800000                 Yes
# 719                       alchemy of souls     305500000                 Yes
# 12537                             sex/life     301900000                 Yes
# 1789                      better call saul     295500000                  No
# 12558                      shadow and bone     292400000                 Yes
# 5197                     gabby's dollhouse     290100000                 Yes
# 11044                            peppa pig     276000000                  No
# 13556                          sweet tooth     271300000                 Yes
# 2323                            bridgerton     270000000                 Yes
# 12139                             s.w.a.t.     268200000                  No
# 4582                                 fubar     266200000                 Yes
# 4386                        emily in paris     262700000                 Yes
# 7447                          kaleidoscope     252500000                 Yes
# 15383                           the mother     249900000                 Yes
# 748                    alice in borderland     249800000                 Yes
# 1988                          black mirror     248900000                  No
# 10990                       peaky blinders     244400000                  No
# 10766                            outlander     238300000                  No
# 17891             wrong side of the tracks     237700000                  No
#
#       Release Date originalTitle Year_Country
# 5379    2021-02-24           NaN          NaN
# 15439   2023-03-23           NaN          NaN
# 17960   2018-12-26           NaN          NaN
# 10764   2020-04-15           NaN          NaN
# 16178          NaT           NaN          NaN
# 14713   2022-12-30         더 글로리          NaN
# 7904    2011-09-05           NaN          NaN
# 2999    2020-05-31           NaN          NaN
# 13394          NaT           NaN         2011
# 14084          NaT           NaN          NaN
# 8882    2021-06-10           NaN          NaN
# 5704           NaT           NaN          NaN
# 17542   2022-11-23           NaN          NaN
# 2304           NaT           NaN          NaN
# 11514   2023-05-04           NaN          NaN
# 5361           NaT           NaN          NaN
# 5078           NaT           NaN         1994
# 8643    2017-07-23           NaN          NaN
# 14044          NaT           NaN          NaN
# 12576          NaT           NaN         U.S.
# 10116          NaT           NaN         2018
# 2355           NaT           NaN          NaN
# 8497    2020-02-13           NaN          NaN
# 4843    2021-02-03           NaN          NaN
# 10104   2020-04-27           NaN          NaN
# 15479          NaT           NaN         U.S.
# 17343   2022-02-25           NaN          NaN
# 10807          NaT           NaN          NaN
# 12436          NaT           NaN          NaN
# 14595          NaT           NaN         2014
# 9937           NaT           NaN          NaN
# 15275   2022-04-20       Pálpito          NaN
# 719     2022-06-18            환혼          NaN
# 12537   2021-06-25           NaN          NaN
# 1789    2015-02-08           NaN          NaN
# 12558   2021-04-23           NaN          NaN
# 5197    2021-01-05           NaN          NaN
# 11044          NaT           NaN          NaN
# 13556   2021-06-04           NaN          NaN
# 2323    2020-12-25           NaN          NaN
# 12139          NaT           NaN         2017
# 4582    2023-05-25           NaN          NaN
# 4386    2020-10-02           NaN          NaN
# 7447    2023-01-01           NaN          NaN
# 15383   2023-05-12           NaN          NaN
# 748     2020-12-10      今際の国のアリス          NaN
# 1988    2013-02-28           NaN          NaN
# 10990   2014-09-30           NaN          NaN
# 10766   2016-03-31           NaN          NaN
# 17891   2022-05-20     Entrevías          NaN

# %%
# Extracting the year from 'Release Date' to new column called 'release_year'
df['release_year'] = df['Release Date'].dt.strftime('%Y')
df.head()
# Out:
#                   Title  Hours Viewed Available Globally? Release Date  \
# 5379    ginny & georgia     967200000                 Yes   2021-02-24
# 15439   the night agent     812100000                 Yes   2023-03-23
# 17960               you     766300000                 Yes   2018-12-26
# 10764       outer banks     740400000                 Yes   2020-04-15
# 16178  the walking dead     738600000                  No          NaT
#
#       originalTitle Year_Country release_year
# 5379            NaN          NaN         2021
# 15439           NaN          NaN         2023
# 17960           NaN          NaN         2018
# 10764           NaN          NaN         2020
# 16178           NaN          NaN          NaN

# %%
# Read the 'Netflix_Engagement_Plus.csv'data file as engagement_df
title_df = pd.read_csv("Resources/data_title.tsv",sep = '\t') 
title_df.head()
# Out:
# C:\Users\Joey\AppData\Local\Temp\ipykernel_9288\146890606.py:2: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   title_df = pd.read_csv("Resources/data_title.tsv",sep = '\t')
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
# Read the 'data_ratings.tsv'data file as score_df
score_df = pd.read_csv("Resources/data_ratings.tsv",sep = '\t') 
score_df.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      2008
# 1  tt0000002            5.7       270
# 2  tt0000003            6.5      1926
# 3  tt0000004            5.4       178
# 4  tt0000005            6.2      2701

# %%
# Check what titleTypes IMDB's database has
title_df['titleType'].unique()
# Out:
# array(['short', 'movie', 'tvShort', 'tvMovie', 'tvSeries', 'tvEpisode',
#        'tvMiniSeries', 'tvSpecial', 'video', 'videoGame', 'tvPilot'],
#       dtype=object)

# %%
# Eliminate titleTypes which are not needed for Netflix data matching and format IMDB title information to match Netflix Data
Filtered_title_df = title_df[~title_df['titleType'].isin(['videoGame', 'tvPilot', 'tvEpisode', 'short', 'video', 'tvMovie', 'tvShort'])]
Filtered_title_df = Filtered_title_df.rename(columns={'primaryTitle':'Title'})
Filtered_title_df['Title'] = Filtered_title_df['Title'].str.lower()
Filtered_title_df['originalTitle'] = Filtered_title_df['originalTitle'].str.lower()
Filtered_title_df
# Out:
#              tconst titleType  \
# 8         tt0000009     movie
# 144       tt0000147     movie
# 498       tt0000502     movie
# 570       tt0000574     movie
# 587       tt0000591     movie
# ...             ...       ...
# 10415815  tt9916678  tvSeries
# 10415816  tt9916680     movie
# 10415828  tt9916706     movie
# 10415838  tt9916730     movie
# 10415848  tt9916754     movie
#
#                                                       Title  \
# 8                                                miss jerry
# 144                           the corbett-fitzsimmons fight
# 498                                                bohemios
# 570                             the story of the kelly gang
# 587                                        the prodigal son
# ...                                                     ...
# 10415815                                         acelerados
# 10415816  de la ilusión al desconcierto: cine colombiano...
# 10415828                                    dankyavar danka
# 10415838                                             6 gunn
# 10415848                     chico albuquerque - revelações
#
#                                               originalTitle isAdult startYear  \
# 8                                                miss jerry       0      1894
# 144                           the corbett-fitzsimmons fight       0      1897
# 498                                                bohemios       0      1905
# 570                             the story of the kelly gang       0      1906
# 587                                       l'enfant prodigue       0      1907
# ...                                                     ...     ...       ...
# 10415815                                         acelerados       0      2019
# 10415816  de la ilusión al desconcierto: cine colombiano...       0      2007
# 10415828                                    dankyavar danka       0      2013
# 10415838                                             6 gunn       0      2017
# 10415848                     chico albuquerque - revelações       0      2013
#
#          endYear runtimeMinutes                      genres
# 8             \N             45                     Romance
# 144           \N            100      Documentary,News,Sport
# 498           \N            100                          \N
# 570           \N             70  Action,Adventure,Biography
# 587           \N             90                       Drama
# ...          ...            ...                         ...
# 10415815      \N             \N                      Comedy
# 10415816      \N            100                 Documentary
# 10415828      \N             \N                      Comedy
# 10415838      \N            116                       Drama
# 10415848      \N             49                 Documentary
#
# [1017061 rows x 9 columns]

# %%
# Merge Netflix and IMDB information
Merged_df = pd.merge(df,Filtered_title_df, on='Title', how='left')
Merged_df
# Out:
#                     Title  Hours Viewed Available Globally? Release Date  \
# 0         ginny & georgia     967200000                 Yes   2021-02-24
# 1         the night agent     812100000                 Yes   2023-03-23
# 2                     you     766300000                 Yes   2018-12-26
# 3                     you     766300000                 Yes   2018-12-26
# 4                     you     766300000                 Yes   2018-12-26
# ...                   ...           ...                 ...          ...
# 36740       endless night        100000                  No          NaT
# 36741  enemy at the gates        100000                  No          NaT
# 36742             area 51        100000                  No          NaT
# 36743     my god!! father        100000                  No          NaT
# 36744       the grown-ups        100000                  No          NaT
#
#       originalTitle_x Year_Country release_year      tconst titleType  \
# 0                 NaN          NaN         2021  tt10813940  tvSeries
# 1                 NaN          NaN         2023  tt13918776  tvSeries
# 2                 NaN          NaN         2018   tt0134224     movie
# 3                 NaN          NaN         2018   tt0960886     movie
# 4                 NaN          NaN         2018   tt1487831  tvSeries
# ...               ...          ...          ...         ...       ...
# 36740             NaN          NaN          NaN   tt6605564     movie
# 36741             NaN          NaN          NaN   tt0215750     movie
# 36742             NaN          NaN          NaN   tt1519461     movie
# 36743             NaN          NaN          NaN         NaN       NaN
# 36744             NaN          NaN          NaN   tt6618178     movie
#
#           originalTitle_y isAdult startYear endYear runtimeMinutes  \
# 0         ginny & georgia       0      2021      \N             \N
# 1         the night agent       0      2023      \N             45
# 2                     you       0      1968      \N             \N
# 3                     you       0      2009      \N             84
# 4                     you       0      1982    1987             60
# ...                   ...     ...       ...     ...            ...
# 36740       endless night       0      1972      \N             86
# 36741  enemy at the gates       0      2001      \N            131
# 36742             area 51       0      2015      \N             91
# 36743                 NaN     NaN       NaN     NaN            NaN
# 36744       the grown-ups       0      2016      \N             82
#
#                       genres
# 0               Comedy,Drama
# 1      Action,Drama,Thriller
# 2                      Drama
# 3                      Drama
# 4                  Talk-Show
# ...                      ...
# 36740        Horror,Thriller
# 36741       Action,Drama,War
# 36742  Horror,Mystery,Sci-Fi
# 36743                    NaN
# 36744            Documentary
#
# [36745 rows x 15 columns]

# %%
# Attempt 1: Match IMDB data to Netflix based on titles alone
Merged_df['Duplicated_values'] = Merged_df['Title'].duplicated(keep=False)
Title_matching_df = Merged_df
Title_matching_df = Title_matching_df[Title_matching_df['Duplicated_values'] == False]
Title_matching_df = Title_matching_df[Title_matching_df['tconst'].notnull()]
Title_matching_df
# Out:
#                      Title  Hours Viewed Available Globally? Release Date  \
# 0          ginny & georgia     967200000                 Yes   2021-02-24
# 1          the night agent     812100000                 Yes   2023-03-23
# 10             outer banks     740400000                 Yes   2020-04-15
# 18               cocomelon     601200000                  No   2020-05-31
# 27          grey's anatomy     560300000                  No          NaT
# ...                    ...           ...                 ...          ...
# 36730  terror in resonance        100000                  No          NaT
# 36731              arianna        100000                  No          NaT
# 36741   enemy at the gates        100000                  No          NaT
# 36742              area 51        100000                  No          NaT
# 36744        the grown-ups        100000                  No          NaT
#
#       originalTitle_x Year_Country release_year      tconst     titleType  \
# 0                 NaN          NaN         2021  tt10813940      tvSeries
# 1                 NaN          NaN         2023  tt13918776      tvSeries
# 10                NaN          NaN         2020  tt10293938      tvSeries
# 18                NaN          NaN         2020  tt12427840      tvSeries
# 27                NaN          NaN          NaN   tt0413573      tvSeries
# ...               ...          ...          ...         ...           ...
# 36730          残響のテロル          NaN          NaN   tt3613454  tvMiniSeries
# 36731             NaN          NaN          NaN   tt4908430         movie
# 36741             NaN          NaN          NaN   tt0215750         movie
# 36742             NaN          NaN          NaN   tt1519461         movie
# 36744             NaN          NaN          NaN   tt6618178         movie
#
#           originalTitle_y isAdult startYear endYear runtimeMinutes  \
# 0         ginny & georgia       0      2021      \N             \N
# 1         the night agent       0      2023      \N             45
# 10            outer banks       0      2020      \N             50
# 18              cocomelon       0      2018    2022              4
# 27         grey's anatomy       0      2005      \N             41
# ...                   ...     ...       ...     ...            ...
# 36730    zankyô no teroru       0      2014    2014             23
# 36731             arianna       0      2015      \N             84
# 36741  enemy at the gates       0      2001      \N            131
# 36742             area 51       0      2015      \N             91
# 36744       the grown-ups       0      2016      \N             82
#
#                       genres  Duplicated_values
# 0               Comedy,Drama              False
# 1      Action,Drama,Thriller              False
# 10        Action,Crime,Drama              False
# 18          Animation,Family              False
# 27             Drama,Romance              False
# ...                      ...                ...
# 36730  Animation,Crime,Drama              False
# 36731          Drama,Mystery              False
# 36741       Action,Drama,War              False
# 36742  Horror,Mystery,Sci-Fi              False
# 36744            Documentary              False
#
# [7435 rows x 16 columns]

# %%
# Format data down to only what is needed for the purpose of analysis
Title_matching_df = Title_matching_df.filter(items=['Title', 'Hours Viewed','Available Globally?','Release Date',
                                                'originalTitle_x', 'Year_Country', 'release_year', 'tconst', 
                                                'titleType', 'startYear', 'endYear', 'runtimeMinutes', 'genres'])
Title_matching_df = Title_matching_df.rename(columns={'originalTitle_x':'originalTitle'})

# %%
# Merge title matching data with score data, and remove titles which did not pull any score information from their related IMDB entry
Title_matching_df = pd.merge(Title_matching_df,score_df, left_on='tconst', right_on='tconst', how='left')
Title_matching_df = Title_matching_df[Title_matching_df['averageRating'].notnull()]
Title_matching_df
# Out:
#                     Title  Hours Viewed Available Globally? Release Date  \
# 0         ginny & georgia     967200000                 Yes   2021-02-24
# 1         the night agent     812100000                 Yes   2023-03-23
# 2             outer banks     740400000                 Yes   2020-04-15
# 3               cocomelon     601200000                  No   2020-05-31
# 4          grey's anatomy     560300000                  No          NaT
# ...                   ...           ...                 ...          ...
# 7430  terror in resonance        100000                  No          NaT
# 7431              arianna        100000                  No          NaT
# 7432   enemy at the gates        100000                  No          NaT
# 7433              area 51        100000                  No          NaT
# 7434        the grown-ups        100000                  No          NaT
#
#      originalTitle Year_Country release_year      tconst     titleType  \
# 0              NaN          NaN         2021  tt10813940      tvSeries
# 1              NaN          NaN         2023  tt13918776      tvSeries
# 2              NaN          NaN         2020  tt10293938      tvSeries
# 3              NaN          NaN         2020  tt12427840      tvSeries
# 4              NaN          NaN          NaN   tt0413573      tvSeries
# ...            ...          ...          ...         ...           ...
# 7430        残響のテロル          NaN          NaN   tt3613454  tvMiniSeries
# 7431           NaN          NaN          NaN   tt4908430         movie
# 7432           NaN          NaN          NaN   tt0215750         movie
# 7433           NaN          NaN          NaN   tt1519461         movie
# 7434           NaN          NaN          NaN   tt6618178         movie
#
#      startYear endYear runtimeMinutes                 genres  averageRating  \
# 0         2021      \N             \N           Comedy,Drama            7.5
# 1         2023      \N             45  Action,Drama,Thriller            7.5
# 2         2020      \N             50     Action,Crime,Drama            7.5
# 3         2018    2022              4       Animation,Family            4.3
# 4         2005      \N             41          Drama,Romance            7.6
# ...        ...     ...            ...                    ...            ...
# 7430      2014    2014             23  Animation,Crime,Drama            7.8
# 7431      2015      \N             84          Drama,Mystery            6.2
# 7432      2001      \N            131       Action,Drama,War            7.5
# 7433      2015      \N             91  Horror,Mystery,Sci-Fi            4.3
# 7434      2016      \N             82            Documentary            7.7
#
#       numVotes
# 0      77525.0
# 1      99387.0
# 2      74515.0
# 3        895.0
# 4     333561.0
# ...        ...
# 7430   13133.0
# 7431     720.0
# 7432  274251.0
# 7433   14994.0
# 7434     303.0
#
# [7329 rows x 15 columns]

# %%
# Attempt 2: Match years, check for titles that have the same 'startYear' and 'release_year'
Year_matching_df = Merged_df[Merged_df['Duplicated_values'] == True]
Year_matching_df = Year_matching_df[Year_matching_df['startYear']==Year_matching_df['release_year']]
Year_matching_df['Duplicated_values'] = Year_matching_df['Title'].duplicated(keep=False)
Year_matching_df = Year_matching_df[Year_matching_df['Duplicated_values'] == False]
Year_matching_df = Year_matching_df[Year_matching_df['tconst'].notnull()]
Year_matching_df
# Out:
#                    Title  Hours Viewed Available Globally? Release Date  \
# 14             the glory     622800000                 Yes   2022-12-30
# 29             wednesday     507700000                 Yes   2022-11-23
# 63               lucifer     434300000                  No   2017-07-23
# 94     never have i ever     341300000                 Yes   2020-04-27
# 118             sex/life     301900000                 Yes   2021-06-25
# ...                  ...           ...                 ...          ...
# 31622         mercury 13        100000                 Yes   2018-04-20
# 32191           whispers        100000                 Yes   2020-06-11
# 32244               slam        100000                 Yes   2017-04-15
# 32298      strong island        100000                 Yes   2017-09-15
# 32330           upstarts        100000                 Yes   2019-10-18
#
#       originalTitle_x Year_Country release_year      tconst titleType  \
# 14              더 글로리          NaN         2022  tt21344706  tvSeries
# 29                NaN          NaN         2022  tt13443470  tvSeries
# 63                NaN          NaN         2017   tt5096524     movie
# 94                NaN          NaN         2020  tt10062292  tvSeries
# 118               NaN          NaN         2021  tt10839422  tvSeries
# ...               ...          ...          ...         ...       ...
# 31622             NaN          NaN         2018   tt8139850     movie
# 32191           وساوس          NaN         2020  tt12410506  tvSeries
# 32244             NaN          NaN         2017   tt7503744  tvSeries
# 32298             NaN          NaN         2017   tt5873150     movie
# 32330             NaN          NaN         2019  tt11066130     movie
#
#          originalTitle_y isAdult startYear endYear runtimeMinutes  \
# 14          deo geullori       0      2022      \N             50
# 29             wednesday       0      2022      \N             45
# 63               lucifer       0      2017      \N            110
# 94     never have i ever       0      2020    2023             30
# 118             sex/life       0      2021    2023             45
# ...                  ...     ...       ...     ...            ...
# 31622         mercury 13       0      2018      \N             78
# 32191           whispers       0      2020    2020             \N
# 32244               slam       0      2017    2018             \N
# 32298      strong island       0      2017      \N            107
# 32330           upstarts       0      2019      \N            112
#
#                        genres  Duplicated_values
# 14     Drama,Mystery,Thriller              False
# 29       Comedy,Crime,Fantasy              False
# 63                     Horror              False
# 94               Comedy,Drama              False
# 118      Comedy,Drama,Romance              False
# ...                       ...                ...
# 31622             Documentary              False
# 32191        Mystery,Thriller              False
# 32244               Game-Show              False
# 32298       Crime,Documentary              False
# 32330                   Drama              False
#
# [703 rows x 16 columns]

# %%
# Format data down to only what is needed for the purpose of analysis
Year_matching_df = Year_matching_df.filter(items=['Title', 'Hours Viewed','Available Globally?','Release Date',
                                                'originalTitle_x', 'Year_Country', 'release_year', 'tconst', 
                                                'titleType', 'startYear', 'endYear', 'runtimeMinutes', 'genres'])
Year_matching_df = Year_matching_df.rename(columns={'originalTitle_x':'originalTitle'})
Year_matching_df.head()
# Out:
#                  Title  Hours Viewed Available Globally? Release Date  \
# 14           the glory     622800000                 Yes   2022-12-30
# 29           wednesday     507700000                 Yes   2022-11-23
# 63             lucifer     434300000                  No   2017-07-23
# 94   never have i ever     341300000                 Yes   2020-04-27
# 118           sex/life     301900000                 Yes   2021-06-25
#
#     originalTitle Year_Country release_year      tconst titleType startYear  \
# 14          더 글로리          NaN         2022  tt21344706  tvSeries      2022
# 29            NaN          NaN         2022  tt13443470  tvSeries      2022
# 63            NaN          NaN         2017   tt5096524     movie      2017
# 94            NaN          NaN         2020  tt10062292  tvSeries      2020
# 118           NaN          NaN         2021  tt10839422  tvSeries      2021
#
#     endYear runtimeMinutes                  genres
# 14       \N             50  Drama,Mystery,Thriller
# 29       \N             45    Comedy,Crime,Fantasy
# 63       \N            110                  Horror
# 94     2023             30            Comedy,Drama
# 118    2023             45    Comedy,Drama,Romance

# %%
# Merge year matching data with score data, and remove titles which did not pull any score information from their related IMDB entry
Year_matching_df = pd.merge(Year_matching_df,score_df, left_on='tconst', right_on='tconst', how='left')
Year_matching_df = Year_matching_df[Year_matching_df['averageRating'].notnull()]
Year_matching_df.head()
# Out:
#                Title  Hours Viewed Available Globally? Release Date  \
# 0          the glory     622800000                 Yes   2022-12-30
# 1          wednesday     507700000                 Yes   2022-11-23
# 2            lucifer     434300000                  No   2017-07-23
# 3  never have i ever     341300000                 Yes   2020-04-27
# 4           sex/life     301900000                 Yes   2021-06-25
#
#   originalTitle Year_Country release_year      tconst titleType startYear  \
# 0         더 글로리          NaN         2022  tt21344706  tvSeries      2022
# 1           NaN          NaN         2022  tt13443470  tvSeries      2022
# 2           NaN          NaN         2017   tt5096524     movie      2017
# 3           NaN          NaN         2020  tt10062292  tvSeries      2020
# 4           NaN          NaN         2021  tt10839422  tvSeries      2021
#
#   endYear runtimeMinutes                  genres  averageRating  numVotes
# 0      \N             50  Drama,Mystery,Thriller            8.1   23866.0
# 1      \N             45    Comedy,Crime,Fantasy            8.1  342374.0
# 2      \N            110                  Horror            6.1      11.0
# 3    2023             30            Comedy,Drama            7.9   76801.0
# 4    2023             45    Comedy,Drama,Romance            5.6   29864.0

# %%
# Merge Title and Year matching data into one DF
Complete_data_df = pd.concat([Title_matching_df, Year_matching_df], ignore_index=True, sort=False)
Complete_data_df
# Out:
#                                   Title  Hours Viewed Available Globally?  \
# 0                       ginny & georgia     967200000                 Yes
# 1                       the night agent     812100000                 Yes
# 2                           outer banks     740400000                 Yes
# 3                             cocomelon     601200000                  No
# 4                        grey's anatomy     560300000                  No
# ...                                 ...           ...                 ...
# 8014  seth rogen's hilarity for charity        100000                 Yes
# 8015                         mercury 13        100000                 Yes
# 8016                           whispers        100000                 Yes
# 8017                      strong island        100000                 Yes
# 8018                           upstarts        100000                 Yes
#
#      Release Date originalTitle Year_Country release_year      tconst  \
# 0      2021-02-24           NaN          NaN         2021  tt10813940
# 1      2023-03-23           NaN          NaN         2023  tt13918776
# 2      2020-04-15           NaN          NaN         2020  tt10293938
# 3      2020-05-31           NaN          NaN         2020  tt12427840
# 4             NaT           NaN          NaN          NaN   tt0413573
# ...           ...           ...          ...          ...         ...
# 8014   2018-04-06           NaN          NaN         2018   tt8178116
# 8015   2018-04-20           NaN          NaN         2018   tt8139850
# 8016   2020-06-11         وساوس          NaN         2020  tt12410506
# 8017   2017-09-15           NaN          NaN         2017   tt5873150
# 8018   2019-10-18           NaN          NaN         2019  tt11066130
#
#       titleType startYear endYear runtimeMinutes                 genres  \
# 0      tvSeries      2021      \N             \N           Comedy,Drama
# 1      tvSeries      2023      \N             45  Action,Drama,Thriller
# 2      tvSeries      2020      \N             50     Action,Crime,Drama
# 3      tvSeries      2018    2022              4       Animation,Family
# 4      tvSeries      2005      \N             41          Drama,Romance
# ...         ...       ...     ...            ...                    ...
# 8014  tvSpecial      2018      \N             70                 Comedy
# 8015      movie      2018      \N             78            Documentary
# 8016   tvSeries      2020    2020             \N       Mystery,Thriller
# 8017      movie      2017      \N            107      Crime,Documentary
# 8018      movie      2019      \N            112                  Drama
#
#       averageRating  numVotes
# 0               7.5   77525.0
# 1               7.5   99387.0
# 2               7.5   74515.0
# 3               4.3     895.0
# 4               7.6  333561.0
# ...             ...       ...
# 8014            5.0    2486.0
# 8015            7.0    1273.0
# 8016            5.5     391.0
# 8017            6.4    4071.0
# 8018            6.7     923.0
#
# [8019 rows x 15 columns]

# %%
# Re-merge and compare completed data with original Netflix Dataframe to find missing titles
Missing_data_df = pd.concat([df, Complete_data_df], ignore_index=False, sort=False)
Missing_data_df['Duplicated_values'] = Missing_data_df['Title'].duplicated(keep=False)
Missing_data_df = Missing_data_df[Missing_data_df['Duplicated_values'] == False]
Missing_data_df = Missing_data_df.filter(items=['Title', 'Hours Viewed','Available Globally?','Release Date', 'originalTitle', 'Year_Country', 'release_year'])
Missing_data_df = Missing_data_df.sort_values(by=['Hours Viewed'], ascending=False)
Missing_data_df
# Out:
#                                            Title  Hours Viewed  \
# 17960                                        you     766300000
# 16178                           the walking dead     738600000
# 7904                            la reina del sur     616800000
# 13394                                      suits     599300000
# 14084                              the blacklist     596900000
# ...                                          ...           ...
# 16348                        they are everywhere        100000
# 16345  there's a reason for the love i'm wearing        100000
# 7107                     jackie chan's project a        100000
# 8063                         le fils du français        100000
# 9800                             my god!! father        100000
#
#       Available Globally? Release Date originalTitle Year_Country release_year
# 17960                 Yes   2018-12-26           NaN          NaN         2018
# 16178                  No          NaT           NaN          NaN          NaN
# 7904                   No   2011-09-05           NaN          NaN         2011
# 13394                 Yes          NaT           NaN         2011          NaN
# 14084                  No          NaT           NaN          NaN          NaN
# ...                   ...          ...           ...          ...          ...
# 16348                  No          NaT           NaN          NaN          NaN
# 16345                  No          NaT  着飾る恋には理由があって          NaN          NaN
# 7107                   No          NaT           NaN          NaN          NaN
# 8063                   No          NaT           NaN          NaN          NaN
# 9800                   No          NaT           NaN          NaN          NaN
#
# [7080 rows x 7 columns]

# %%
# Attempt 3: Merge with original title data from IMDB and title data from Netflix
Original_title_matching_df = pd.merge(Missing_data_df,Filtered_title_df, left_on='Title', right_on='originalTitle', how='left')
Original_title_matching_df
# Out:
#                                          Title_x  Hours Viewed  \
# 0                                            you     766300000
# 1                                            you     766300000
# 2                                            you     766300000
# 3                                            you     766300000
# 4                                            you     766300000
# ...                                          ...           ...
# 21763                        they are everywhere        100000
# 21764  there's a reason for the love i'm wearing        100000
# 21765                    jackie chan's project a        100000
# 21766                        le fils du français        100000
# 21767                            my god!! father        100000
#
#       Available Globally? Release Date originalTitle_x Year_Country  \
# 0                     Yes   2018-12-26             NaN          NaN
# 1                     Yes   2018-12-26             NaN          NaN
# 2                     Yes   2018-12-26             NaN          NaN
# 3                     Yes   2018-12-26             NaN          NaN
# 4                     Yes   2018-12-26             NaN          NaN
# ...                   ...          ...             ...          ...
# 21763                  No          NaT             NaN          NaN
# 21764                  No          NaT    着飾る恋には理由があって          NaN
# 21765                  No          NaT             NaN          NaN
# 21766                  No          NaT             NaN          NaN
# 21767                  No          NaT             NaN          NaN
#
#       release_year      tconst titleType              Title_y  \
# 0             2018   tt0134224     movie                  you
# 1             2018   tt0960886     movie                  you
# 2             2018   tt1487831  tvSeries                  you
# 3             2018  tt20123090     movie                  you
# 4             2018   tt7025370     movie                  you
# ...            ...         ...       ...                  ...
# 21763          NaN         NaN       NaN                  NaN
# 21764          NaN         NaN       NaN                  NaN
# 21765          NaN         NaN       NaN                  NaN
# 21766          NaN   tt0211372     movie  the son of français
# 21767          NaN         NaN       NaN                  NaN
#
#            originalTitle_y isAdult startYear endYear runtimeMinutes  \
# 0                      you       0      1968      \N             \N
# 1                      you       0      2009      \N             84
# 2                      you       0      1982    1987             60
# 3                      you       0      2013      \N            326
# 4                      you       0      2018      \N             48
# ...                    ...     ...       ...     ...            ...
# 21763                  NaN     NaN       NaN     NaN            NaN
# 21764                  NaN     NaN       NaN     NaN            NaN
# 21765                  NaN     NaN       NaN     NaN            NaN
# 21766  le fils du français       0      1999      \N            107
# 21767                  NaN     NaN       NaN     NaN            NaN
#
#                         genres
# 0                        Drama
# 1                        Drama
# 2                    Talk-Show
# 3                        Drama
# 4                        Drama
# ...                        ...
# 21763                      NaN
# 21764                      NaN
# 21765                      NaN
# 21766  Adventure,Comedy,Family
# 21767                      NaN
#
# [21768 rows x 16 columns]

# %%
# Merge original title data with score data and sort for most voted entries, then keep only the most voted entry to elimniate extraneous information
Original_title_matching_df = pd.merge(Original_title_matching_df,score_df, left_on='tconst', right_on='tconst', how='left')
Original_title_matching_df = Original_title_matching_df.sort_values(by=['numVotes'], ascending=False)
Original_title_matching_df = Original_title_matching_df.drop_duplicates(subset=['Title_x'])
Original_title_matching_df = Original_title_matching_df[Original_title_matching_df['tconst'].notnull()]
Original_title_matching_df
# Out:
#                                                  Title_x  Hours Viewed  \
# 1277                                     the dark knight      18300000
# 2859                                           inception       7400000
# 1515                                       the godfather      15400000
# 1586                                           gladiator      14900000
# 2412                             the wolf of wall street       9100000
# ...                                                  ...           ...
# 21573                                           the rope        100000
# 21613  thomas & friends: marvelous machinery: a new a...        100000
# 21629                                      jail breakers        100000
# 21660                                               zion        100000
# 21738                                     winning streak        100000
#
#       Available Globally? Release Date originalTitle_x Year_Country  \
# 1277                   No          NaT             NaN         2008
# 2859                   No          NaT             NaN          NaN
# 1515                   No          NaT             NaN          NaN
# 1586                   No          NaT             NaN         2000
# 2412                   No          NaT             NaN          NaN
# ...                   ...          ...             ...          ...
# 21573                  No          NaT             NaN          NaN
# 21613                  No          NaT             NaN          NaN
# 21629                  No          NaT             NaN          NaN
# 21660                 Yes   2018-08-10             NaN          NaN
# 21738                  No          NaT             NaN          NaN
#
#       release_year      tconst titleType  \
# 1277           NaN   tt0468569     movie
# 2859           NaN   tt1375666     movie
# 1515           NaN   tt0068646     movie
# 1586           NaN   tt0172495     movie
# 2412           NaN   tt0993846     movie
# ...            ...         ...       ...
# 21573          NaN  tt15127510  tvSeries
# 21613          NaN  tt14594718     movie
# 21629          NaN  tt28660225     movie
# 21660         2018  tt30330486     movie
# 21738          NaN   tt0128114  tvSeries
#
#                                                  Title_y  \
# 1277                                     the dark knight
# 2859                                           inception
# 1515                                       the godfather
# 1586                                           gladiator
# 2412                             the wolf of wall street
# ...                                                  ...
# 21573                                           the rope
# 21613  thomas & friends: marvelous machinery: a new a...
# 21629                                      jail breakers
# 21660                                               zion
# 21738                                     winning streak
#
#                                          originalTitle_y isAdult startYear  \
# 1277                                     the dark knight       0      2008
# 2859                                           inception       0      2010
# 1515                                       the godfather       0      1972
# 1586                                           gladiator       0      2000
# 2412                             the wolf of wall street       0      2013
# ...                                                  ...     ...       ...
# 21573                                           the rope       0        \N
# 21613  thomas & friends: marvelous machinery: a new a...       0      2020
# 21629                                      jail breakers       0      2023
# 21660                                               zion       0        \N
# 21738                                     winning streak       0      1974
#
#       endYear runtimeMinutes                   genres  averageRating  \
# 1277       \N            152       Action,Crime,Drama            9.0
# 2859       \N            148  Action,Adventure,Sci-Fi            8.8
# 1515       \N            175              Crime,Drama            9.2
# 1586       \N            155   Action,Adventure,Drama            8.5
# 2412       \N            180   Biography,Comedy,Crime            8.2
# ...       ...            ...                      ...            ...
# 21573      \N             \N                    Drama            NaN
# 21613      \N             \N                Animation            NaN
# 21629      \N             51                   Comedy            NaN
# 21660      \N             \N                       \N            NaN
# 21738    1975             30                Game-Show            NaN
#
#         numVotes
# 1277   2812745.0
# 2859   2497034.0
# 1515   1973440.0
# 1586   1584096.0
# 2412   1536866.0
# ...          ...
# 21573        NaN
# 21613        NaN
# 21629        NaN
# 21660        NaN
# 21738        NaN
#
# [3691 rows x 18 columns]

# %%
# Format data down to only what is needed for the purpose of analysis
Original_title_matching_df = Original_title_matching_df.filter(items=['Title_x', 'Hours Viewed','Available Globally?','Release Date',
                                                'originalTitle_x', 'Year_Country', 'release_year', 'tconst', 
                                                'titleType', 'startYear', 'endYear', 'runtimeMinutes', 'genres', 'averageRating', 'numVotes'])
Original_title_matching_df = Original_title_matching_df.rename(columns={'originalTitle_x':'originalTitle', 'Title_x':'Title'})
Original_title_matching_df.head()
# Out:
#                         Title  Hours Viewed Available Globally? Release Date  \
# 1277          the dark knight      18300000                  No          NaT
# 2859                inception       7400000                  No          NaT
# 1515            the godfather      15400000                  No          NaT
# 1586                gladiator      14900000                  No          NaT
# 2412  the wolf of wall street       9100000                  No          NaT
#
#      originalTitle Year_Country release_year     tconst titleType startYear  \
# 1277           NaN         2008          NaN  tt0468569     movie      2008
# 2859           NaN          NaN          NaN  tt1375666     movie      2010
# 1515           NaN          NaN          NaN  tt0068646     movie      1972
# 1586           NaN         2000          NaN  tt0172495     movie      2000
# 2412           NaN          NaN          NaN  tt0993846     movie      2013
#
#      endYear runtimeMinutes                   genres  averageRating   numVotes
# 1277      \N            152       Action,Crime,Drama            9.0  2812745.0
# 2859      \N            148  Action,Adventure,Sci-Fi            8.8  2497034.0
# 1515      \N            175              Crime,Drama            9.2  1973440.0
# 1586      \N            155   Action,Adventure,Drama            8.5  1584096.0
# 2412      \N            180   Biography,Comedy,Crime            8.2  1536866.0

# %%
# Merge Originial title matching data with already completed data from previous attempts
Complete_data_df = pd.concat([Complete_data_df, Original_title_matching_df], ignore_index=True, sort=False)
Complete_data_df = Complete_data_df.sort_values(by=['Hours Viewed'], ascending=False)
Complete_data_df
# Out:
#                                Title  Hours Viewed Available Globally?  \
# 0                    ginny & georgia     967200000                 Yes
# 1                    the night agent     812100000                 Yes
# 8240                             you     766300000                 Yes
# 2                        outer banks     740400000                 Yes
# 8032                the walking dead     738600000                  No
# ...                              ...           ...                 ...
# 6980               the cursed lesson        100000                  No
# 6981                  ah boys to men        100000                  No
# 6982                        mix tape        100000                  No
# 6983   fareast: from berlin to tokyo        100000                  No
# 11709                 winning streak        100000                  No
#
#       Release Date                    originalTitle Year_Country release_year  \
# 0       2021-02-24                              NaN          NaN         2021
# 1       2023-03-23                              NaN          NaN         2023
# 8240    2018-12-26                              NaN          NaN         2018
# 2       2020-04-15                              NaN          NaN         2020
# 8032           NaT                              NaN          NaN          NaN
# ...            ...                              ...          ...          ...
# 6980           NaT                             요가학원          NaN          NaN
# 6981           NaT                              NaN          NaN          NaN
# 6982           NaT                              NaN          NaN          NaN
# 6983           NaT  fernOST – von Berlin nach Tokio          NaN          NaN
# 11709          NaT                              NaN          NaN          NaN
#
#            tconst titleType startYear endYear runtimeMinutes  \
# 0      tt10813940  tvSeries      2021      \N             \N
# 1      tt13918776  tvSeries      2023      \N             45
# 8240    tt7335184  tvSeries      2018    2024             45
# 2      tt10293938  tvSeries      2020      \N             50
# 8032    tt1520211  tvSeries      2010    2022             44
# ...           ...       ...       ...     ...            ...
# 6980   tt13478812     movie      2020      \N             93
# 6981    tt2525596     movie      2012      \N            110
# 6982    tt0378369     movie      2003      \N             97
# 6983    tt3328154  tvSeries      2013    2013             43
# 11709   tt0128114  tvSeries      1974    1975             30
#
#                         genres  averageRating   numVotes
# 0                 Comedy,Drama            7.5    77525.0
# 1        Action,Drama,Thriller            7.5    99387.0
# 8240       Crime,Drama,Romance            7.7   289182.0
# 2           Action,Crime,Drama            7.5    74515.0
# 8032     Drama,Horror,Thriller            8.1  1058747.0
# ...                        ...            ...        ...
# 6980   Horror,Mystery,Thriller            4.7      211.0
# 6981                    Comedy            6.1      598.0
# 6982                    Comedy            8.1       15.0
# 6983               Documentary            7.8       73.0
# 11709                Game-Show            NaN        NaN
#
# [11710 rows x 15 columns]

# %%
# Export final information to csv file
Complete_data_df.to_csv("Netflix_data.csv", index=False)
