# %% [markdown]
# # Project 3 : Binging Netflix Data

# %% [markdown]
# ## Part 1 --- ETL (Extract, Transform, Load)

# %%
# Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import json

# %% [markdown]
# ### Wrangling Data
# - Base dataset from kaggle, some entries missing IMDb score;
# - Merging with two datasets from IMDb, one contains title+id, one contains score+id, merge on title;

# %%
# Read the 'Netflix_Engagement_Plus.csv'data file as engagement_df
engagement_df = pd.read_csv("Resources/Netflix_Engagement_Plus.csv")
engagement_df.head()
# Out:
#                                  Title Available Globally? Release Date  \
# 0            The Night Agent: Season 1                 Yes   2023-03-23
# 1            Ginny & Georgia: Season 2                 Yes   2023-01-05
# 2   The Glory: Season 1 // 더 글로리: 시즌 1                 Yes   2022-12-30
# 3                  Wednesday: Season 1                 Yes   2022-11-23
# 4  Queen Charlotte: A Bridgerton Story                 Yes   2023-05-04
#
#    Hours Viewed  Number of Ratings  Rating                              Genre  \
# 0     812100000             7696.0     6.0  ['Biography', 'Drama', 'History']
# 1     665100000             5216.0     5.7     ['Comedy', 'Drama', 'Romance']
# 2     622800000            11869.0     8.4                          ['Short']
# 3     507700000                NaN     NaN                      ['Talk-Show']
# 4     503000000            50077.0     7.4    ['Drama', 'History', 'Romance']
#
#                                            Key Words  \
# 0  persian empire,empire,5th century b.c.,achaeme...
# 1  producer,three word title,headstrong,arranged ...
# 2                                                NaN
# 3                                      youtube video
# 4  prequel,queen,historical,england,queen charlot...
#
#                                          Description
# 0                                                NaN
# 1  The film follows headstrong Ginny who meets Su...
# 2                                                NaN
# 3  MsMojo counts down the top 10 Wednesday (2022)...
# 4  Betrothed against her will to King George, you...

# %%
# Read the 'data_title.tsv'data file as title_df
title_df = pd.read_csv("Resources/data_title.tsv",sep = '\t') 
title_df.head()
# Out:
# C:\Users\Joey\AppData\Local\Temp\ipykernel_6036\3383494270.py:2: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   title_df = pd.read_csv("Resources/data_title.tsv",sep = '\t')
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
# Read the 'data.tsv'data file as score_df
score_df = pd.read_csv("Resources/data_ratings.tsv",sep = '\t') 
score_df.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      2008
# 1  tt0000002            5.7       270
# 2  tt0000003            6.5      1926
# 3  tt0000004            5.4       178
# 4  tt0000005            6.2      2701

# %%
# Filtering out the df with missing ratings part, name it 'missing_rating_engagement_df'
missing_rating_engagement_df = engagement_df[engagement_df['Rating'].isnull()]
missing_rating_engagement_df
# Out:
#                                Title Available Globally? Release Date  \
# 3                Wednesday: Season 1                 Yes   2022-11-23
# 7              Outer Banks: Season 3                 Yes   2023-02-23
# 10                Manifest: Season 4                 Yes   2022-11-04
# 11      Kaleidoscope: Limited Series                 Yes   2023-01-01
# 12            Firefly Lane: Season 2                 Yes   2022-12-02
# ...                              ...                 ...          ...
# 18325  حكايات بنات الجزء ١: Season 2                  No          NaN
# 18326  حكايات بنات الجزء ١: Season 3                  No          NaN
# 18329                      두근두근 내 인생                  No          NaN
# 18330                         라디오 스타                  No          NaN
# 18331                         선생 김봉두                  No          NaN
#
#        Hours Viewed  Number of Ratings  Rating                     Genre  \
# 3         507700000                NaN     NaN             ['Talk-Show']
# 7         402500000                NaN     NaN                       NaN
# 10        262600000                NaN     NaN  ['Documentary', 'Short']
# 11        252500000                NaN     NaN                       NaN
# 12        251500000                NaN     NaN                       NaN
# ...             ...                ...     ...                       ...
# 18325        100000                NaN     NaN                       NaN
# 18326        100000                NaN     NaN                       NaN
# 18329        100000                NaN     NaN                       NaN
# 18330        100000                NaN     NaN                       NaN
# 18331        100000                NaN     NaN                       NaN
#
#            Key Words                                        Description
# 3      youtube video  MsMojo counts down the top 10 Wednesday (2022)...
# 7                NaN                                                NaN
# 10               NaN                                                NaN
# 11               NaN                                                NaN
# 12               NaN                                                NaN
# ...              ...                                                ...
# 18325            NaN                                                NaN
# 18326            NaN                                                NaN
# 18329            NaN                                                NaN
# 18330            NaN                                                NaN
# 18331            NaN                                                NaN
#
# [4110 rows x 9 columns]

# %%
# Merge title_df and score_df datasets to create score_titile_df with both title and score
score_titile_df = pd.merge(title_df,score_df,on="tconst",how="outer")
score_titile_df.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres  \
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short
#
#    averageRating  numVotes
# 0            5.7    2008.0
# 1            5.7     270.0
# 2            6.5    1926.0
# 3            5.4     178.0
# 4            6.2    2701.0

# %%
# Merge score_titile_df with missing_rating_engagement_df
rating_engagement_df = pd.merge(missing_rating_engagement_df,score_titile_df,left_on="Title",right_on="originalTitle",how="inner")
rating_engagement_df
# Out:
#      Title Available Globally? Release Date  Hours Viewed  Number of Ratings  \
# 0      AKA                 Yes   2023-04-28     120000000                NaN
# 1      AKA                 Yes   2023-04-28     120000000                NaN
# 2      AKA                 Yes   2023-04-28     120000000                NaN
# 3      AKA                 Yes   2023-04-28     120000000                NaN
# 4      AKA                 Yes   2023-04-28     120000000                NaN
# ...    ...                 ...          ...           ...                ...
# 2657  Zulu                  No          NaN        100000                NaN
# 2658  Zulu                  No          NaN        100000                NaN
# 2659  Zulu                  No          NaN        100000                NaN
# 2660  Zulu                  No          NaN        100000                NaN
# 2661  Zulu                  No          NaN        100000                NaN
#
#       Rating Genre Key Words Description      tconst  titleType primaryTitle  \
# 0        NaN   NaN       NaN         NaN   tt0317052      movie          AKA
# 1        NaN   NaN       NaN         NaN  tt10730418      short          AKA
# 2        NaN   NaN       NaN         NaN   tt1117442  tvEpisode          AKA
# 3        NaN   NaN       NaN         NaN  tt13444004      short          AKA
# 4        NaN   NaN       NaN         NaN  tt13815300  tvEpisode          AKA
# ...      ...   ...       ...         ...         ...        ...          ...
# 2657     NaN   NaN       NaN         NaN   tt0058777      movie         Zulu
# 2658     NaN   NaN       NaN         NaN  tt21418892      movie         Zulu
# 2659     NaN   NaN       NaN         NaN   tt2249221      movie         Zulu
# 2660     NaN   NaN       NaN         NaN   tt7232874  tvEpisode         Zulu
# 2661     NaN   NaN       NaN         NaN   tt9337844  tvEpisode         Zulu
#
#      originalTitle isAdult startYear endYear runtimeMinutes  \
# 0              AKA       0      2002      \N            123
# 1              AKA       0      2018      \N             17
# 2              AKA       0      2007      \N             43
# 3              AKA       0      2020      \N             15
# 4              AKA       0      2015      \N             \N
# ...            ...     ...       ...     ...            ...
# 2657          Zulu       0      1964      \N            138
# 2658          Zulu       0      2005      \N             50
# 2659          Zulu       0      2013      \N            110
# 2660          Zulu       0      2015      \N             18
# 2661          Zulu       0      2008      \N             \N
#
#                           genres  averageRating  numVotes
# 0                  Drama,Romance            6.3    1239.0
# 1       Adventure,Family,Fantasy            NaN       NaN
# 2             Action,Crime,Drama            8.1      36.0
# 3                          Short            NaN       NaN
# 4                Music,Talk-Show            NaN       NaN
# ...                          ...            ...       ...
# 2657           Drama,History,War            7.7   41872.0
# 2658                 Documentary            NaN       NaN
# 2659          Action,Crime,Drama            6.7   19668.0
# 2660  Comedy,Documentary,History            7.7       8.0
# 2661                  Reality-TV            NaN       NaN
#
# [2662 rows x 20 columns]

# %%
# Filtering out the entries with ratings in order to narrow down the wanted matching title
rating_engagement_df = rating_engagement_df[rating_engagement_df['averageRating'].notnull()]
rating_engagement_df
# Out:
#                   Title Available Globally? Release Date  Hours Viewed  \
# 0                   AKA                 Yes   2023-04-28     120000000
# 2                   AKA                 Yes   2023-04-28     120000000
# 6                   AKA                 Yes   2023-04-28     120000000
# 10    Stranger Things 3                 Yes   2019-07-04      67000000
# 11         The Gray Man                 Yes   2022-07-22      58300000
# ...                 ...                 ...          ...           ...
# 2652        Wild Venice                  No          NaN        100000
# 2656                Zog                  No          NaN        100000
# 2657               Zulu                  No          NaN        100000
# 2659               Zulu                  No          NaN        100000
# 2660               Zulu                  No          NaN        100000
#
#       Number of Ratings  Rating                             Genre Key Words  \
# 0                   NaN     NaN                               NaN       NaN
# 2                   NaN     NaN                               NaN       NaN
# 6                   NaN     NaN                               NaN       NaN
# 10                  NaN     NaN               ['Short', 'Comedy']       NaN
# 11                  NaN     NaN                               NaN       NaN
# ...                 ...     ...                               ...       ...
# 2652                NaN     NaN              ['Comedy', 'Family']       NaN
# 2656                NaN     NaN  ['Animation', 'Short', 'Comedy']       NaN
# 2657                NaN     NaN                               NaN       NaN
# 2659                NaN     NaN                               NaN       NaN
# 2660                NaN     NaN                               NaN       NaN
#
#                                             Description      tconst  \
# 0                                                   NaN   tt0317052
# 2                                                   NaN   tt1117442
# 6                                                   NaN  tt27197387
# 10                                                  NaN   tt8046346
# 11                                                  NaN   tt0360615
# ...                                                 ...         ...
# 2652                                                NaN  tt27571435
# 2656  Almost 250,000 years ago, Zog, the first femin...   tt9109620
# 2657                                                NaN   tt0058777
# 2659                                                NaN   tt2249221
# 2660                                                NaN   tt7232874
#
#       titleType       primaryTitle      originalTitle isAdult startYear  \
# 0         movie                AKA                AKA       0      2002
# 2     tvEpisode                AKA                AKA       0      2007
# 6         movie                AKA                AKA       0      2023
# 10    tvEpisode  Stranger Things 3  Stranger Things 3       0      2017
# 11        movie       The Gray Man       The Gray Man       0      2002
# ...         ...                ...                ...     ...       ...
# 2652      movie        Wild Venice        Wild Venice       0      2014
# 2656    tvMovie                Zog                Zog       0      2018
# 2657      movie               Zulu               Zulu       0      1964
# 2659      movie               Zulu               Zulu       0      2013
# 2660  tvEpisode               Zulu               Zulu       0      2015
#
#      endYear runtimeMinutes                      genres  averageRating  \
# 0         \N            123               Drama,Romance            6.3
# 2         \N             43          Action,Crime,Drama            8.1
# 6         \N            122       Action,Crime,Thriller            6.6
# 10        \N             \N     Action,Adventure,Comedy            9.4
# 11        \N             87          Action,Crime,Drama            7.9
# ...      ...            ...                         ...            ...
# 2652      \N             52                 Documentary            6.6
# 2656      \N             26     Animation,Comedy,Family            7.3
# 2657      \N            138           Drama,History,War            7.7
# 2659      \N            110          Action,Crime,Drama            6.7
# 2660      \N             18  Comedy,Documentary,History            7.7
#
#       numVotes
# 0       1239.0
# 2         36.0
# 6      12119.0
# 10        16.0
# 11        42.0
# ...        ...
# 2652       8.0
# 2656    1326.0
# 2657   41872.0
# 2659   19668.0
# 2660       8.0
#
# [1015 rows x 20 columns]

# %%
# Checking the data types of all columns
rating_engagement_df.dtypes
# Out:
# Title                   object
# Available Globally?     object
# Release Date            object
# Hours Viewed             int64
# Number of Ratings      float64
# Rating                 float64
# Genre                   object
# Key Words               object
# Description             object
# tconst                  object
# titleType               object
# primaryTitle            object
# originalTitle           object
# isAdult                 object
# startYear               object
# endYear                 object
# runtimeMinutes          object
# genres                  object
# averageRating          float64
# numVotes               float64
# dtype: object

# %%
# Converting the data type of 'Release Date' to datetime in order to extract the year
rating_engagement_df['Release Date'] = pd.to_datetime(rating_engagement_df['Release Date'])
# Out:
# C:\Users\Joey\AppData\Local\Temp\ipykernel_6036\1863630452.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rating_engagement_df['Release Date'] = pd.to_datetime(rating_engagement_df['Release Date'])

# %%
# Extracting the year from 'Release Date' to new column called 'release_year'
rating_engagement_df['release_year'] = rating_engagement_df['Release Date'].dt.strftime('%Y')
rating_engagement_df
# Out:
# C:\Users\Joey\AppData\Local\Temp\ipykernel_6036\2794742527.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rating_engagement_df['release_year'] = rating_engagement_df['Release Date'].dt.strftime('%Y')
#                   Title Available Globally? Release Date  Hours Viewed  \
# 0                   AKA                 Yes   2023-04-28     120000000
# 2                   AKA                 Yes   2023-04-28     120000000
# 6                   AKA                 Yes   2023-04-28     120000000
# 10    Stranger Things 3                 Yes   2019-07-04      67000000
# 11         The Gray Man                 Yes   2022-07-22      58300000
# ...                 ...                 ...          ...           ...
# 2652        Wild Venice                  No          NaT        100000
# 2656                Zog                  No          NaT        100000
# 2657               Zulu                  No          NaT        100000
# 2659               Zulu                  No          NaT        100000
# 2660               Zulu                  No          NaT        100000
#
#       Number of Ratings  Rating                             Genre Key Words  \
# 0                   NaN     NaN                               NaN       NaN
# 2                   NaN     NaN                               NaN       NaN
# 6                   NaN     NaN                               NaN       NaN
# 10                  NaN     NaN               ['Short', 'Comedy']       NaN
# 11                  NaN     NaN                               NaN       NaN
# ...                 ...     ...                               ...       ...
# 2652                NaN     NaN              ['Comedy', 'Family']       NaN
# 2656                NaN     NaN  ['Animation', 'Short', 'Comedy']       NaN
# 2657                NaN     NaN                               NaN       NaN
# 2659                NaN     NaN                               NaN       NaN
# 2660                NaN     NaN                               NaN       NaN
#
#                                             Description      tconst  ...  \
# 0                                                   NaN   tt0317052  ...
# 2                                                   NaN   tt1117442  ...
# 6                                                   NaN  tt27197387  ...
# 10                                                  NaN   tt8046346  ...
# 11                                                  NaN   tt0360615  ...
# ...                                                 ...         ...  ...
# 2652                                                NaN  tt27571435  ...
# 2656  Almost 250,000 years ago, Zog, the first femin...   tt9109620  ...
# 2657                                                NaN   tt0058777  ...
# 2659                                                NaN   tt2249221  ...
# 2660                                                NaN   tt7232874  ...
#
#            primaryTitle      originalTitle isAdult startYear endYear  \
# 0                   AKA                AKA       0      2002      \N
# 2                   AKA                AKA       0      2007      \N
# 6                   AKA                AKA       0      2023      \N
# 10    Stranger Things 3  Stranger Things 3       0      2017      \N
# 11         The Gray Man       The Gray Man       0      2002      \N
# ...                 ...                ...     ...       ...     ...
# 2652        Wild Venice        Wild Venice       0      2014      \N
# 2656                Zog                Zog       0      2018      \N
# 2657               Zulu               Zulu       0      1964      \N
# 2659               Zulu               Zulu       0      2013      \N
# 2660               Zulu               Zulu       0      2015      \N
#
#      runtimeMinutes                      genres averageRating  numVotes  \
# 0               123               Drama,Romance           6.3    1239.0
# 2                43          Action,Crime,Drama           8.1      36.0
# 6               122       Action,Crime,Thriller           6.6   12119.0
# 10               \N     Action,Adventure,Comedy           9.4      16.0
# 11               87          Action,Crime,Drama           7.9      42.0
# ...             ...                         ...           ...       ...
# 2652             52                 Documentary           6.6       8.0
# 2656             26     Animation,Comedy,Family           7.3    1326.0
# 2657            138           Drama,History,War           7.7   41872.0
# 2659            110          Action,Crime,Drama           6.7   19668.0
# 2660             18  Comedy,Documentary,History           7.7       8.0
#
#       release_year
# 0             2023
# 2             2023
# 6             2023
# 10            2019
# 11            2022
# ...            ...
# 2652           NaN
# 2656           NaN
# 2657           NaN
# 2659           NaN
# 2660           NaN
#
# [1015 rows x 21 columns]

# %%
# Keep the scores that has the same 'startYear' and 'release_year'
manual_rating_engagement_df = rating_engagement_df[rating_engagement_df['startYear']==rating_engagement_df['release_year']]
manual_rating_engagement_df
# Out:
#                                                   Title Available Globally?  \
# 6                                                   AKA                 Yes
# 14                                         The Gray Man                 Yes
# 16                                         The Gray Man                 Yes
# 17                                         The Gray Man                 Yes
# 19                                         Blood & Gold                 Yes
# ...                                                 ...                 ...
# 2221                                    Louis C.K. 2017                 Yes
# 2446  Jen Kirkman: I'm Gonna Die Alone (And I Feel F...                 Yes
# 2489            Nicole Byer: BBW (Big Beautiful Weirdo)                 Yes
# 2504                        Patton Oswalt: Annihilation                 Yes
# 2531                                      Swearnet Live                 Yes
#
#      Release Date  Hours Viewed  Number of Ratings  Rating              Genre  \
# 6      2023-04-28     120000000                NaN     NaN                NaN
# 14     2022-07-22      58300000                NaN     NaN                NaN
# 16     2022-07-22      58300000                NaN     NaN                NaN
# 17     2022-07-22      58300000                NaN     NaN                NaN
# 19     2023-05-26      51600000                NaN     NaN                NaN
# ...           ...           ...                ...     ...                ...
# 2221   2017-04-04        200000                NaN     NaN  ['Short', 'News']
# 2446   2015-05-22        100000                NaN     NaN                NaN
# 2489   2021-12-07        100000                NaN     NaN                NaN
# 2504   2017-10-17        100000                NaN     NaN                NaN
# 2531   2014-09-30        100000                NaN     NaN                NaN
#
#                                               Key Words  \
# 6                                                   NaN
# 14                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 19                                                  NaN
# ...                                                 ...
# 2221  reference to louis c.k.,reference to harvey we...
# 2446                                                NaN
# 2489                                                NaN
# 2504                                                NaN
# 2531                                                NaN
#
#                                             Description      tconst  ...  \
# 6                                                   NaN  tt27197387  ...
# 14                                                  NaN   tt1649418  ...
# 16                                                  NaN  tt21400610  ...
# 17                                                  NaN  tt21433764  ...
# 19                                                  NaN  tt18073328  ...
# ...                                                 ...         ...  ...
# 2221  Sexual allegations erupt everywhere in Hollywo...   tt6736782  ...
# 2446                                                NaN   tt4703660  ...
# 2489                                                NaN  tt15204492  ...
# 2504                                                NaN   tt7026230  ...
# 2531                                                NaN   tt3599642  ...
#
#                                            primaryTitle  \
# 6                                                   AKA
# 14                                         The Gray Man
# 16                                         The Gray Man
# 17                                         The Gray Man
# 19                                         Blood & Gold
# ...                                                 ...
# 2221                                    Louis C.K. 2017
# 2446  Jen Kirkman: I'm Gonna Die Alone (And I Feel F...
# 2489            Nicole Byer: BBW (Big Beautiful Weirdo)
# 2504                        Patton Oswalt: Annihilation
# 2531                                      Swearnet Live
#
#                                           originalTitle isAdult startYear  \
# 6                                                   AKA       0      2023
# 14                                         The Gray Man       0      2022
# 16                                         The Gray Man       0      2022
# 17                                         The Gray Man       0      2022
# 19                                         Blood & Gold       0      2023
# ...                                                 ...     ...       ...
# 2221                                    Louis C.K. 2017       0      2017
# 2446  Jen Kirkman: I'm Gonna Die Alone (And I Feel F...       0      2015
# 2489            Nicole Byer: BBW (Big Beautiful Weirdo)       0      2021
# 2504                        Patton Oswalt: Annihilation       0      2017
# 2531                                      Swearnet Live       0      2014
#
#      endYear runtimeMinutes                 genres averageRating  numVotes  \
# 6         \N            122  Action,Crime,Thriller           6.6   12119.0
# 14        \N            122        Action,Thriller           6.5  229717.0
# 16        \N             \N                 Comedy           7.9      14.0
# 17        \N             \N                 Comedy           6.9      17.0
# 19        \N             98       Action,Drama,War           6.5   15493.0
# ...      ...            ...                    ...           ...       ...
# 2221      \N             74                 Comedy           7.6   10738.0
# 2446      \N             78                 Comedy           6.8    1636.0
# 2489      \N             65                 Comedy           5.9     618.0
# 2504      \N             66                 Comedy           7.3    2490.0
# 2531      \N             75                 Comedy           5.4     589.0
#
#       release_year
# 6             2023
# 14            2022
# 16            2022
# 17            2022
# 19            2023
# ...            ...
# 2221          2017
# 2446          2015
# 2489          2021
# 2504          2017
# 2531          2014
#
# [70 rows x 21 columns]

# %%
test_df = title_df[title_df["primaryTitle"] == "#NoFilter"]
test_df
# Out:
#              tconst  titleType primaryTitle originalTitle isAdult startYear  \
# 2311652  tt12428990  tvEpisode    #NoFilter     #NoFilter       0      2017
# 6268781  tt26368084   tvSeries    #NoFilter    Sem Filtro       0      2023
# 6917152  tt28664132      short    #NoFilter     #NoFilter       0      2023
# 7491157   tt3411820      short    #NoFilter     #NoFilter       0      2013
# 7512525   tt3460710  tvEpisode    #NoFilter     #NoFilter       0      2013
# 8087511   tt4767674  tvEpisode    #NoFilter     #NoFilter       0      2016
# 8535870   tt5781880   tvSeries    #NoFilter     #NoFilter       0      2016
# 9614938   tt8174472  tvEpisode    #NoFilter     #NoFilter       0      2018
# 9640800   tt8230776   tvSeries    #NoFilter     #NoFilter       0      2018
# 9681895   tt8320494    tvShort    #NoFilter     #NoFilter       0      2018
#
#         endYear runtimeMinutes              genres
# 2311652      \N             \N         Documentary
# 6268781      \N             30              Comedy
# 6917152      \N             22  Comedy,Drama,Short
# 7491157      \N              6         Drama,Short
# 7512525      \N             \N              Comedy
# 8087511      \N             23       Drama,Romance
# 8535870      \N             \N           Talk-Show
# 9614938      \N             \N              Comedy
# 9640800    2018             17              Comedy
# 9681895      \N             17        Comedy,Short

# %%
test_df[test_df['titleType'] == "tvSeries"]
# Out:
#              tconst titleType primaryTitle originalTitle isAdult startYear  \
# 6268781  tt26368084  tvSeries    #NoFilter    Sem Filtro       0      2023
# 8535870   tt5781880  tvSeries    #NoFilter     #NoFilter       0      2016
# 9640800   tt8230776  tvSeries    #NoFilter     #NoFilter       0      2018
#
#         endYear runtimeMinutes     genres
# 6268781      \N             30     Comedy
# 8535870      \N             \N  Talk-Show
# 9640800    2018             17     Comedy

# %%
test2_df = title_df[title_df["titleType"] == "tvSeries"]
test2_df
# Out:
#              tconst titleType                  primaryTitle  \
# 34971     tt0035599  tvSeries   Voice of Firestone Televues
# 35172     tt0035803  tvSeries      The German Weekly Review
# 37600     tt0038276  tvSeries             You Are an Artist
# 38434     tt0039120  tvSeries                     Americana
# 38435     tt0039121  tvSeries                Birthday Party
# ...             ...       ...                           ...
# 10415589  tt9916210  tvSeries         Rumpole of the Bailey
# 10415592  tt9916216  tvSeries  Kalyanam Mudhal Kadhal Varai
# 10415593  tt9916218  tvSeries                  Lost in Food
# 10415673  tt9916380  tvSeries           Meie aasta Aafrikas
# 10415815  tt9916678  tvSeries                    Acelerados
#
#                          originalTitle isAdult startYear endYear  \
# 34971      Voice of Firestone Televues       0      1943    1947
# 35172         Die Deutsche Wochenschau       0      1940    1945
# 37600                You Are an Artist       0      1946    1955
# 38434                        Americana       0      1947    1949
# 38435                   Birthday Party       0      1947    1949
# ...                                ...     ...       ...     ...
# 10415589         Rumpole of the Bailey       0        \N      \N
# 10415592  Kalyanam Mudhal Kadhal Varai       0      2014    2017
# 10415593                  Lost in Food       0      2016    2017
# 10415673           Meie aasta Aafrikas       0      2019      \N
# 10415815                    Acelerados       0      2019      \N
#
#          runtimeMinutes                   genres
# 34971                15                       \N
# 35172                12         Documentary,News
# 37600                15                Talk-Show
# 38434                30         Family,Game-Show
# 38435                30                   Family
# ...                 ...                      ...
# 10415589             \N                       \N
# 10415592             22                  Romance
# 10415593             \N                Talk-Show
# 10415673             43  Adventure,Comedy,Family
# 10415815             \N                   Comedy
#
# [254087 rows x 9 columns]

# %%
test2_df = test2_df[test2_df["startYear"] == "2012"]
test2_df
# Out:
#              tconst titleType                      primaryTitle  \
# 199475    tt0207877  tvSeries                      Counterpoint
# 263377    tt0275126  tvSeries        The Di Palma Forum at UNLV
# 285835    tt0298637  tvSeries                    Escape with ET
# 321427    tt0335630  tvSeries  Onkel Reje og børnenes brevkasse
# 467868    tt0487001  tvSeries                     NFL Primetime
# ...             ...       ...                               ...
# 10398963  tt9880204  tvSeries                       Royal Rasoi
# 10399215  tt9880738  tvSeries                      Night and Me
# 10400048  tt9882602  tvSeries              Tube Tube: Back2Work
# 10403171  tt9889344  tvSeries   Silver Spoon, Sterling Shackles
# 10405170  tt9893740  tvSeries                       Lizard Cops
#
#                              originalTitle isAdult startYear endYear  \
# 199475                        Counterpoint       0      2012      \N
# 263377          The Di Palma Forum at UNLV       0      2012      \N
# 285835                      Escape with ET       0      2012      \N
# 321427    Onkel Reje og børnenes brevkasse       0      2012      \N
# 467868                       NFL Primetime       0      2012      \N
# ...                                    ...     ...       ...     ...
# 10398963                       Royal Rasoi       0      2012    2013
# 10399215                      Night and Me       0      2012      \N
# 10400048              Tube Tube: Back2Work       0      2012    2012
# 10403171   Silver Spoon, Sterling Shackles       0      2012    2012
# 10405170                       Lizard Cops       0      2012      \N
#
#          runtimeMinutes                genres
# 199475               \N                    \N
# 263377               \N                    \N
# 285835               \N                Family
# 321427               \N                    \N
# 467868               60  News,Sport,Talk-Show
# ...                 ...                   ...
# 10398963             25             Talk-Show
# 10399215             \N                Family
# 10400048             \N                    \N
# 10403171             \N                 Drama
# 10405170             \N             Animation
#
# [9094 rows x 9 columns]

# %%
test2_df = title_df[title_df['originalTitle'].str.contains('The Glory')]
test2_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 test2_df = title_df[title_df['originalTitle'].str.contains('The Glory')]
#       2 test2_df
#
# File ~\anaconda3\envs\dev\lib\site-packages\pandas\core\frame.py:3751, in DataFrame.__getitem__(self, key)
#    3748     return self.where(key)
#    3750 # Do we have a (boolean) 1d indexer?
# -> 3751 if com.is_bool_indexer(key):
#    3752     return self._getitem_bool_array(key)
#    3754 # We are left with two options: a single key, and a collection of keys,
#    3755 # We interpret tuples as collections only for non-MultiIndex
#
# File ~\anaconda3\envs\dev\lib\site-packages\pandas\core\common.py:134, in is_bool_indexer(key)
#     130     na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     131     if lib.infer_dtype(key_array) == "boolean" and isna(key_array).any():
#     132         # Don't raise on e.g. ["A", "B", np.nan], see
#     133         #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# --> 134         raise ValueError(na_msg)
#     135     return False
#     136 return True
#
# ValueError: Cannot mask with non-boolean array containing NA / NaN values

# %%
title_df
# Out:
#              tconst  titleType               primaryTitle  \
# 0         tt0000001      short                 Carmencita
# 1         tt0000002      short     Le clown et ses chiens
# 2         tt0000003      short             Pauvre Pierrot
# 3         tt0000004      short                Un bon bock
# 4         tt0000005      short           Blacksmith Scene
# ...             ...        ...                        ...
# 10415893  tt9916848  tvEpisode              Episode #3.17
# 10415894  tt9916850  tvEpisode              Episode #3.19
# 10415895  tt9916852  tvEpisode              Episode #3.20
# 10415896  tt9916856      short                   The Wind
# 10415897  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                       originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                        Carmencita       0      1894      \N              1
# 1            Le clown et ses chiens       0      1892      \N              5
# 2                    Pauvre Pierrot       0      1892      \N              4
# 3                       Un bon bock       0      1892      \N             12
# 4                  Blacksmith Scene       0      1893      \N              1
# ...                             ...     ...       ...     ...            ...
# 10415893              Episode #3.17       0      2009      \N             \N
# 10415894              Episode #3.19       0      2010      \N             \N
# 10415895              Episode #3.20       0      2010      \N             \N
# 10415896                   The Wind       0      2015      \N             27
# 10415897  Horrid Henry Knows It All       0      2014      \N             10
#
#                               genres
# 0                  Documentary,Short
# 1                    Animation,Short
# 2           Animation,Comedy,Romance
# 3                    Animation,Short
# 4                       Comedy,Short
# ...                              ...
# 10415893         Action,Drama,Family
# 10415894         Action,Drama,Family
# 10415895         Action,Drama,Family
# 10415896                       Short
# 10415897  Adventure,Animation,Comedy
#
# [10415898 rows x 9 columns]

# %%
test2_df = title_df[title_df['originalTitle'].notnull()]
test2_df
# Out:
#              tconst  titleType               primaryTitle  \
# 0         tt0000001      short                 Carmencita
# 1         tt0000002      short     Le clown et ses chiens
# 2         tt0000003      short             Pauvre Pierrot
# 3         tt0000004      short                Un bon bock
# 4         tt0000005      short           Blacksmith Scene
# ...             ...        ...                        ...
# 10415893  tt9916848  tvEpisode              Episode #3.17
# 10415894  tt9916850  tvEpisode              Episode #3.19
# 10415895  tt9916852  tvEpisode              Episode #3.20
# 10415896  tt9916856      short                   The Wind
# 10415897  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                       originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                        Carmencita       0      1894      \N              1
# 1            Le clown et ses chiens       0      1892      \N              5
# 2                    Pauvre Pierrot       0      1892      \N              4
# 3                       Un bon bock       0      1892      \N             12
# 4                  Blacksmith Scene       0      1893      \N              1
# ...                             ...     ...       ...     ...            ...
# 10415893              Episode #3.17       0      2009      \N             \N
# 10415894              Episode #3.19       0      2010      \N             \N
# 10415895              Episode #3.20       0      2010      \N             \N
# 10415896                   The Wind       0      2015      \N             27
# 10415897  Horrid Henry Knows It All       0      2014      \N             10
#
#                               genres
# 0                  Documentary,Short
# 1                    Animation,Short
# 2           Animation,Comedy,Romance
# 3                    Animation,Short
# 4                       Comedy,Short
# ...                              ...
# 10415893         Action,Drama,Family
# 10415894         Action,Drama,Family
# 10415895         Action,Drama,Family
# 10415896                       Short
# 10415897  Adventure,Animation,Comedy
#
# [10415881 rows x 9 columns]

# %%
x = test2_df['titleType'].unique()
x
# Out:
# array(['short', 'movie', 'tvShort', 'tvMovie', 'tvSeries', 'tvEpisode',
#        'tvMiniSeries', 'tvSpecial', 'video', 'videoGame', 'tvPilot'],
#       dtype=object)

# %%
test2_df = test2_df[test2_df['primaryTitle'].str.contains('The Glory')]
test2_df
# Out:
#              tconst  titleType  \
# 5331      tt0005397      short
# 5332      tt0005398      movie
# 7906      tt0008016      movie
# 12991     tt0013184      movie
# 27193     tt0027682      movie
# ...             ...        ...
# 9784658   tt8542786   tvSeries
# 9810497   tt8600302      short
# 9826745   tt8636564  tvEpisode
# 10134119  tt9308606  tvEpisode
# 10237467  tt9531538      movie
#
#                                                primaryTitle  \
# 5331                                The Glory of Clementina
# 5332                                     The Glory of Youth
# 7906                                   The Glory of Yolanda
# 12991                               The Glory of Clementina
# 27193                                       The Glory Trail
# ...                                                     ...
# 9784658                                The Glory Generation
# 9810497                                     The Glory Years
# 9826745          Thick Latina Deep Throats In The Gloryhole
# 10134119  Mazda RX-7 Spirit R: The Glory Days of Japanes...
# 10237467                             The Glory of Emptiness
#
#                                               originalTitle isAdult startYear  \
# 5331                                The Glory of Clementina       0      1915
# 5332                                     The Glory of Youth       0      1915
# 7906                                   The Glory of Yolanda       0      1917
# 12991                               The Glory of Clementina       0      1922
# 27193                                       The Glory Trail       0      1936
# ...                                                     ...     ...       ...
# 9784658                                The Glory Generation       0      2013
# 9810497                                     The Glory Years       0      2019
# 9826745          Thick Latina Deep Throats In The Gloryhole       1      2016
# 10134119  Mazda RX-7 Spirit R: The Glory Days of Japanes...       0      2012
# 10237467                                   Praznik praznine       0      2022
#
#          endYear runtimeMinutes                 genres
# 5331          \N             \N            Drama,Short
# 5332          \N             \N                  Drama
# 7906          \N             50          Drama,Romance
# 12991         \N             60                  Drama
# 27193         \N             65                Western
# ...          ...            ...                    ...
# 9784658     2013             29             Reality-TV
# 9810497       \N             25  Comedy,Short,Thriller
# 9826745       \N             16                  Adult
# 10134119      \N              8                  Sport
# 10237467      \N            100   Crime,Drama,Thriller
#
# [116 rows x 9 columns]

# %%
test2_df = test2_df[test2_df["titleType"] == "tvSeries"]
test2_df
# Out:
#              tconst titleType               primaryTitle  \
# 2695020   tt1315221  tvSeries  The Glory of Team Batista
# 3432071  tt14509642  tvSeries         The Glory of Youth
# 5469781  tt21344706  tvSeries                  The Glory
# 6039468  tt23985694  tvSeries        The Glory of a Life
# 7957415   tt4470788  tvSeries            The Glory Trail
# 8064837   tt4714132  tvSeries          The Glory Is Gone
# 8851327   tt6492378  tvSeries  The Glory of Tang Dynasty
# 9006440   tt6840484  tvSeries             The Glory Hole
# 9784658   tt8542786  tvSeries       The Glory Generation
#
#                    originalTitle isAdult startYear endYear runtimeMinutes  \
# 2695020  Chîmu bachisuta no eikô       0      2008    2014             \N
# 3432071         Hao shou jiu wei       0      2021    2021             \N
# 5469781             Deo geullori       0      2022      \N             50
# 6039468     Shokoh-e Yek Zendegi       0      2017    2017             45
# 7957415          The Glory Trail       0      1965      \N             30
# 8064837          Der Lack ist ab       0      2015    2018             10
# 8851327         Da Tang rong yao       0      2017      \N             \N
# 9006440           The Glory Hole       0      2017      \N             22
# 9784658     The Glory Generation       0      2013    2013             29
#
#                          genres
# 2695020                   Drama
# 3432071                   Drama
# 5469781  Drama,Mystery,Thriller
# 6039468           Drama,Romance
# 7957415             Documentary
# 8064837    Comedy,Drama,Romance
# 8851327   Drama,History,Romance
# 9006440                  Comedy
# 9784658              Reality-TV

# %%
test2_df[test2_df['startYear'] == "2019"]
# Out:
# Empty DataFrame
# Columns: [tconst, titleType, primaryTitle, originalTitle, isAdult, startYear, endYear, runtimeMinutes, genres]
# Index: []

# %%
score_df[score_df['tconst'] == 'tt0386676']
# Out:
#            tconst  averageRating  numVotes
# 217759  tt0386676            9.0    682605
